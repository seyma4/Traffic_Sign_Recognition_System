# %% [markdown]
# # <center><b>🚦 Traffic Sign Recognition **System** (with GTSRB Dataset)</b></center>

# %% [markdown]
# # **1. 📥 Dataset Download**
#
# This command clones the German Traffic Sign dataset from Bitbucket. It contains training, validation, and test sets in .p format, along with a CSV file describing the sign names.

# %%
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# fatal: destination path 'german-traffic-signs' already exists and is not an empty directory.

# %% [markdown]
# Lists the contents of the german-traffic-signs directory to verify that the dataset has been successfully downloaded.

# %%
# !ls german-traffic-signs
# Out:
# signnames.csv  test.p  train.p	valid.p

# %% [markdown]
# # **2. 📚 Library Imports**
# Imports all the necessary libraries for data processing, visualization, image handling, and building the CNN model.

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.layers import Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

import pickle
import pandas as pd
import random
import cv2

# %%
np.random.seed(0)

# %% [markdown]
# # **3. 📦 Loading Dataset**
# Loads the training, validation, and test datasets from .p (Pickle) files. Then separates the features (images) and labels for each dataset.

# %%
with open('german-traffic-signs/train.p', 'rb') as f:
  train_data = pickle.load(f)
with open('german-traffic-signs/valid.p', 'rb') as f:
  val_data = pickle.load(f)
with open('german-traffic-signs/test.p', 'rb') as f:
  test_data = pickle.load(f)



X_train , y_train = train_data['features'], train_data['labels']
X_val , y_val = val_data['features'], val_data['labels']
X_test , y_test = test_data['features'], test_data['labels']

# %% [markdown]
# # **4. 📏 Dataset Shape Check**
# Prints the shape (dimensions) of the training, validation, and test datasets to verify that they are correctly loaded.

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %% [markdown]
# # **5. ✅ Data Integrity Check**
# Uses assert statements to ensure the number of images matches the number of labels and that all images are of size 32x32x3.

# %%
assert(X_train.shape[0] == y_train.shape[0]), "No. of Images is not equals to number of labels"
assert(X_val.shape[0] == y_val.shape[0]), "No. of Images is not equals to number of labels"
assert(X_test.shape[0] == y_test.shape[0]), "No. of Images is not equals to number of labels"

assert(X_train.shape[1:] == (32,32,3)), "The Dimensions of the images are not 32 x 32 x 3"
assert(X_val.shape[1:] == (32,32,3)), "The Dimensions of the images are not 32 x 32 x 3"
assert(X_test.shape[1:] == (32,32,3)), "The Dimensions of the images are not 32 x 32 x 3"

# %% [markdown]
# # **6. 📊 Data Visualization**
#
# *  Reads the CSV file containing traffic sign names.
#
# *   Displays 5 sample images per each of the 43 classes from the training set with their class names.
#
# *   Counts and stores the number of samples per class for later visualization.

# %%
data = pd.read_csv('german-traffic-signs/signnames.csv')
#print(data)

num_of_samples=[]

cols = 5
num_classes = 43

fig, axs = plt.subplots(nrows=num_classes, ncols=cols, figsize=(5,50))
fig.tight_layout()

for i in range(cols):
    for j, row in data.iterrows():
        x_selected = X_train[y_train == j]
        axs[j][i].imshow(x_selected[random.randint(0,(len(x_selected) - 1)), :, :], cmap=plt.get_cmap('gray'))
        axs[j][i].axis("off")
        if i == 2:
          axs[j][i].set_title(str(j) + " - " + row["SignName"])
          num_of_samples.append(len(x_selected))

# %% [markdown]
# # **7. 📈 Dataset Distribution Visualization**
# Prints the number of samples per class and plots a bar chart showing the distribution of images across all 43 classes in the training set.

# %%
print(num_of_samples)
plt.figure(figsize=(12, 4))
plt.bar(range(0, num_classes), num_of_samples)
plt.title("Distribution of the train dataset")
plt.xlabel("Class number")
plt.ylabel("Number of images")
plt.show()
# Out:
# [180, 1980, 2010, 1260, 1770, 1650, 360, 1290, 1260, 1320, 1800, 1170, 1890, 1920, 690, 540, 360, 990, 1080, 180, 300, 270, 330, 450, 240, 1350, 540, 210, 480, 240, 390, 690, 210, 599, 360, 1080, 330, 180, 1860, 270, 300, 210, 210]

# %% [markdown]
# # **8. 🖼️ Sample Image Display**
# * Displays the 3000th image from the training set without axes.
#
# * Prints the shape of this image and its corresponding label.

# %%
plt.imshow(X_train[3000])
plt.axis("off")
print(X_train[3000].shape)
print(y_train[3000])
# Out:
# (32, 32, 3)
# 1

# %% [markdown]
# # **9. ⚫ Grayscale Conversion**
# * Defines a function to convert a color image to grayscale using OpenCV.
#
# * Applies the function to the 3000th training image and displays the grayscale image without axes.
#
# * Prints the new shape of the grayscale image.

# %%
def grayscale(img):
  img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  return img

img = grayscale(X_train[3000])
plt.imshow(img,cmap='gray')
plt.axis("off")
print(img.shape)
# Out:
# (32, 32)

# %% [markdown]
# # **10. 📈 Histogram Equalization**
# * Defines a function to enhance the contrast of a grayscale image using histogram equalization via OpenCV.
#
# * Applies this function to the grayscale image, then displays the enhanced image without axes.
#
# * Prints the shape of the equalized image.

# %%
def equalize(img):
  img = cv2.equalizeHist(img)
  return img


img = equalize(img)
plt.imshow(img, cmap='gray')
plt.axis("off")
print(img.shape)
# Out:
# (32, 32)

# %% [markdown]
# # **11. 🛠️ Image Preprocessing**
# * Defines a preprocessing function that converts images to grayscale, applies histogram equalization, and normalizes pixel values to the range [0,1].
#
# * Applies this preprocessing to all training, validation, and test images.
#
# * Displays a random preprocessed training image without axes.
#
# * Prints the shape of the preprocessed training dataset.

# %%
def preprocessing(img):
  img = grayscale(img)
  img = equalize(img)
  #normalize the images, i.e. convert the pixel values to fit btwn 0 and 1
  img = img/255
  return img

# %%
X_train = np.array(list(map(preprocessing, X_train)))
X_val = np.array(list(map(preprocessing, X_val)))
X_test = np.array(list(map(preprocessing, X_test)))

# %%
plt.imshow(X_train[random.randint(0, len(X_train) - 1)], cmap='gray')
plt.axis('off')  # İstersen eksenleri kaldırmak için
plt.show()
print(X_train.shape)
# Out:
# (34799, 32, 32)

# %% [markdown]
# # **12. 🔄 Data Reshaping & Augmentation**
# * Reshapes the training, validation, and test datasets to include a single grayscale channel (32x32x1).
#
# * Uses Keras' ImageDataGenerator to create augmented images by applying random transformations such as shifts, zoom, shear, and rotation to increase dataset diversity.
#
# * Generates a batch of augmented images and displays 15 of them without axes.
#
# * Prints the shape of the augmented image batch.

# %%
X_train = X_train.reshape(34799, 32, 32, 1)
X_val = X_val.reshape(4410, 32, 32, 1)
X_test = X_test.reshape(12630, 32, 32, 1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


datagen = ImageDataGenerator(width_shift_range=0.1,
                             height_shift_range=0.1,
                            zoom_range=0.2,
                            shear_range=0.1,
                            rotation_range=10.)

datagen.fit(X_train)

# %%
batches = datagen.flow(X_train, y_train, batch_size = 15)
X_batch, y_batch = next(batches)

fig, axs = plt.subplots(1, 15, figsize=(20, 5))
fig.tight_layout()

for i in range(15):
    axs[i].imshow(X_batch[i].reshape(32, 32))
    axs[i].axis("off")

print(X_batch.shape)
# Out:
# (15, 32, 32, 1)

# %% [markdown]
# # **13. 🧠 Model Creation & Data Preparation**
# * Prints dataset shapes.
#
# * Converts labels to one-hot vectors.
#
# * Builds a CNN with Conv2D, MaxPooling, Flatten, Dense, and Dropout layers.
#
# * Uses softmax activation for 43-class classification.
#
# * Compiles model with Adam optimizer and categorical crossentropy loss.

# %%
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 1)
# (4410, 32, 32, 1)
# (12630, 32, 32, 1)

# %%
y_train = to_categorical(y_train, 43)
y_val = to_categorical(y_val, 43)
y_test = to_categorical(y_test, 43)

# %%
def better_model():
    model = Sequential()
    # 1. Conv katmanı input_shape ile
    model.add(Conv2D(60, (5,5), input_shape=(32,32,1), activation='relu'))
    # 2. Conv katmanı input_shape olmadan
    model.add(Conv2D(60, (5,5), activation='relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(30, (3,3), activation='relu'))
    model.add(Conv2D(30, (3,3), activation='relu'))

    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dense(500, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(num_classes, activation='softmax'))  # num_classes mutlaka doğru tanımlı olmalı

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %% [markdown]
# # **14. Model Summary 📋**
# * Creates the CNN model by calling better_model().
#
# * Prints the model architecture summary showing layers and parameters.

# %%
model = better_model()
#print a summary of the model
print(model.summary())
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 60)     │         1,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 60)     │        90,060 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 60)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 10, 10, 30)     │        16,230 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 30)       │         8,130 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 4, 4, 30)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 480)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 500)            │       240,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 500)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 43)             │        21,543 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 378,023 (1.44 MB)
#  Trainable params: 378,023 (1.44 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# # **15. Model Training 🏋️‍♂️**
# * Trains the CNN model using augmented data generator.
#
# * Runs for 15 epochs with validation on validation set.
#
# * Shuffles data each epoch for better training.

# %%
history = model.fit(datagen.flow(X_train, y_train, batch_size=50),
                    steps_per_epoch=2000,
                    epochs=15,
                    validation_data=(X_val, y_val),
                    shuffle=True)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  696/2000 ━━━━━━━━━━━━━━━━━━━━ 31s 24ms/step - accuracy: 0.2832 - loss: 2.6149
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - accuracy: 0.4252 - loss: 2.0475 - val_accuracy: 0.9045 - val_loss: 0.2858
# Epoch 2/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 36s 8ms/step - accuracy: 0.8316 - loss: 0.5511 - val_accuracy: 0.9549 - val_loss: 0.1435
# Epoch 3/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.8979 - loss: 0.3304 - val_accuracy: 0.9730 - val_loss: 0.0821
# Epoch 4/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.9235 - loss: 0.2439 - val_accuracy: 0.9757 - val_loss: 0.0727
# Epoch 5/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9379 - loss: 0.1943 - val_accuracy: 0.9800 - val_loss: 0.0802
# Epoch 6/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9462 - loss: 0.1705 - val_accuracy: 0.9834 - val_loss: 0.0564
# Epoch 7/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.9538 - loss: 0.1504 - val_accuracy: 0.9846 - val_loss: 0.0453
# Epoch 8/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.9580 - loss: 0.1346 - val_accuracy: 0.9839 - val_loss: 0.0510
# Epoch 9/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.9630 - loss: 0.1204 - val_accuracy: 0.9821 - val_loss: 0.0707
# Epoch 10/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.9670 - loss: 0.1036 - val_accuracy: 0.9878 - val_loss: 0.0423
# Epoch 11/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9696 - loss: 0.1035 - val_accuracy: 0.9896 - val_loss: 0.0332
# Epoch 12/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - accuracy: 0.9690 - loss: 0.1001 - val_accuracy: 0.9882 - val_loss: 0.0374
# Epoch 13/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9740 - loss: 0.0857 - val_accuracy: 0.9898 - val_loss: 0.0370
# Epoch 14/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9742 - loss: 0.0849 - val_accuracy: 0.9898 - val_loss: 0.0329
# Epoch 15/15
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9748 - loss: 0.0828 - val_accuracy: 0.9921 - val_loss: 0.0282

# %% [markdown]
# # **16. Plotting Model Loss 📉**
# * Plots training and validation loss over epochs to monitor model performance.
#
# * Helps check if model is learning well or overfitting.

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'])
plt.title('Model Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %% [markdown]
# # **17. Plotting Model Accuracy 🎯**
# * Visualizes training and validation accuracy during training.
#
# * Helps evaluate how well the model is improving.

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
score = model.evaluate(X_test, y_test , verbose = 0)
print("The test score is: ",score[0])
print("The Accuracy score is: ",score[1])
# Out:
# The test score is:  0.10920154303312302
# The Accuracy score is:  0.9719715118408203

# %% [markdown]
# # **18. Fetching an External Image 🌐🖼️**
# * Downloads a traffic sign image from the internet using URL.
#
# * Loads and displays the image for further processing.

# %%
#fetch image

import requests
from PIL import Image
url = 'https://c8.alamy.com/comp/A0RX23/cars-and-automobiles-must-turn-left-ahead-sign-A0RX23.jpg'
r = requests.get(url, stream=True)
img = Image.open(r.raw)
plt.imshow(img, cmap=plt.get_cmap('gray'))

# %% [markdown]
# # **19. Preprocessing the Image ⚙️**
# * Converts image to array, resizes, and applies preprocessing (grayscale, equalize, normalize).
#
# * Prepares image for model prediction.

# %%
#Preprocess image

img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
plt.imshow(img, cmap = plt.get_cmap('gray'))
print(img.shape)
# Out:
# (32, 32)

# %% [markdown]
# # **20. Reshape and Predict 🎯**
# * eshapes image to match model input shape.
#
# * Predicts class probabilities and finds the class with highest probability.
#
# * Prints predicted traffic sign class.

# %%
#Reshape reshape

img = img.reshape(1, 32, 32, 1)

# %%
pred_probs = model.predict(img)                # Modelin tahmin ettiği olasılıklar
pred_class = np.argmax(pred_probs, axis=1)    # En yüksek olasılığın sınıfı

print("The Predicted sign: " + str(pred_class[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# The Predicted sign: 34

# %%
print("X_train[3000] shape:", X_train[3000].shape)
# Out:
# X_train[3000] shape: (32, 32, 1)

# %%
import requests
from PIL import Image
import matplotlib.pyplot as plt
from io import BytesIO

url = 'https://m.media-amazon.com/images/I/51q9vQviSzL._AC_SY1000_.jpg'
response = requests.get(url)
img = Image.open(BytesIO(response.content))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#Preprocess image

img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
plt.imshow(img, cmap = plt.get_cmap('gray'))
print(img.shape)
# Out:
# (32, 32)

# %%
#Reshape reshape

img = img.reshape(1, 32, 32, 1)

# %%
pred_probs = model.predict(img)                # Modelin tahmin ettiği olasılıklar
pred_class = np.argmax(pred_probs, axis=1)    # En yüksek olasılığın sınıfı

print("The Predicted sign: " + str(pred_class[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# The Predicted sign: 4

# %%
import requests
from PIL import Image
import matplotlib.pyplot as plt
from io import BytesIO

url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSH_kNvfa6N4JeC2ZtDoy72yvz_RjN1OgNu1RbWHSyhHN1kLQ9Qydyl5FE&s=10'
response = requests.get(url)
img = Image.open(BytesIO(response.content))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#Preprocess image

img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing(img)
plt.imshow(img, cmap = plt.get_cmap('gray'))
print(img.shape)
# Out:
# (32, 32)

# %%
#Reshape reshape

img = img.reshape(1, 32, 32, 1)

# %%
pred_probs = model.predict(img)                # Modelin tahmin ettiği olasılıklar
pred_class = np.argmax(pred_probs, axis=1)    # En yüksek olasılığın sınıfı

print("The Predicted sign: " + str(pred_class[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# The Predicted sign: 31

# %% [markdown]
# # **21.Confusion Matrix & Class Accuracy 📊**
# This code computes and visualizes the confusion matrix for test predictions, showing how well the model classifies each traffic sign. It also calculates the accuracy for each class and lists the 5 classes with the lowest accuracy.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Test verisi üzerinde tahmin yap
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Confusion matrix hesapla
cm = confusion_matrix(y_true, y_pred_classes)

# Confusion matrix'i görselleştir
plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=data['SignName'],
            yticklabels=data['SignName'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# Sınıf bazında doğrulukları hesapla
class_accuracy = cm.diagonal() / cm.sum(axis=1)

# En kötü performans gösteren 5 sınıfı göster
worst_classes = np.argsort(class_accuracy)[:5]
print("\nEn düşük doğruluğa sahip 5 sınıf:")
for i in worst_classes:
    print(f"Sınıf {i} ({data['SignName'][i]}): %{class_accuracy[i]*100:.2f}")
# Out:
# 395/395 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# En düşük doğruluğa sahip 5 sınıf:
# Sınıf 27 (Pedestrians): %80.00
# Sınıf 6 (End of speed limit (80km/h)): %84.67
# Sınıf 18 (General caution): %85.90
# Sınıf 21 (Double curve): %88.89
# Sınıf 30 (Beware of ice/snow): %89.33
